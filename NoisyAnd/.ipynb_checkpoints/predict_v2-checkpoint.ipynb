# %%
flags = {
    'input_snippet_training_dir': '/projectnb/saenkog/awong1/dataset/kitti/processed3/training',
    'input_snippet_validation_dir': '/projectnb/saenkog/awong1/dataset/kitti/processed3/validation',
    'input_snippet_test_dir': '/projectnb/saenkog/awong1/dataset/kitti/processed3/testing',
    'NUM_EPOCHS': 80,
    'STEPS_PER_EPOCH': 500, # steps_per_epoch = ceil(num_samples / batch_size)
    'INPUT_SHAPE': (128, 128, 1),
    'SEED': 123,
    'SAVE_DIRECTORY': 'conv_mil',
    'MODEL_NAME': 'model35_kitti_input_model35_kitti_input__128x128_80epoch_0.001lr.h5',
    'TRAIN': 0,
    'VISUALIZE': 1,
    'LEARNING_RATE': 0.001,
    'NUM_CLASSES': 2,
    'grayscale_and_no_preprocess': True
}

# %%
import os
import argparse
import random

import tensorflow as tf
print("c1 | tf test gpu avail:", tf.test.is_gpu_available()) # True/False
from tensorflow.python.client import device_lib
print("c1 | device_lib.list_local_devices: ", device_lib.list_local_devices()) # list of DeviceAttributes

import keras
import numpy as np

from keras import backend as K
from keras.layers import Dense, Conv2D, MaxPooling2D
from keras.layers import Layer
from keras.models import Sequential, load_model, Model
from keras.applications.resnet import preprocess_input

from sklearn.metrics import classification_report


from datasets import Mnist
from keras import optimizers
import cv2
import matplotlib.pyplot as plt
from tf_cnnvis import deconv_visualization
# Out:
# c1 | tf test gpu avail: False
# c1 | device_lib.list_local_devices:  [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3018661678624198332
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 52457553835040130
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 11530136499563407281
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:1"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 3618870939655975827
# physical_device_desc: "device: XLA_GPU device"
# ]
# Using TensorFlow backend.
# WARNING:tensorflow:From /projectnb/saenkog/awong1/MIL_CNN_KITTI_2/tf_cnnvis.py:25: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
# Neural Network Class
class NoisyAnd(Layer):
    """Custom NoisyAND layer from the Deep MIL paper"""

    def __init__(self, output_dim=flags['NUM_CLASSES'], **kwargs):
        self.output_dim = output_dim
        super(NoisyAnd, self).__init__(**kwargs)

    def build(self, input_shape):
        self.a = 10  # fixed, controls the slope of the activation
        self.b = self.add_weight(name='b',
                                 shape=(1, input_shape[3]),
                                 initializer='uniform',
                                 trainable=True)
        super(NoisyAnd, self).build(input_shape)  # Be sure to call this at the end

    def call(self, x):
        mean = tf.reduce_mean(x, axis=[1, 2])
        res = (tf.nn.sigmoid(self.a * (mean - self.b)) - tf.nn.sigmoid(-self.a * self.b)) / (
                tf.nn.sigmoid(self.a * (1 - self.b)) - tf.nn.sigmoid(-self.a * self.b))
        return res

    def compute_output_shape(self, input_shape):
        return input_shape[0], input_shape[3]

# %%
def read_and_process_img(img_path, resize_dim=(flags['INPUT_SHAPE'][0], flags['INPUT_SHAPE'][1])):
    if flags['grayscale_and_no_preprocess']:
        img = cv2.imread(img_path, 0)
        img = cv2.resize(img, resize_dim)
        img = np.expand_dims(img, axis=3)
    else:
        img = cv2.imread(img_path)
        img = cv2.resize(img, resize_dim)
        img = preprocess_input(img)
    return img

def build_dataset(dataset_path, get_orig=False):
    X, y, X_orig = [], [], []
    for class_name in sorted(os.listdir(dataset_path)):
        # Traverse image dir
        for img_name in sorted(os.listdir(dataset_path + "/" + class_name)):
            img_path = dataset_path + "/" + class_name + "/" + img_name
            orig_img = cv2.imread(img_path)
            img = read_and_process_img(img_path, resize_dim=(flags['INPUT_SHAPE'][0], flags['INPUT_SHAPE'][1]))
            X.append(img)
            y.append(class_name)
            X_orig.append(orig_img)
    X,y,X_orig= np.array(X), np.array(y), np.array(X_orig)
    
    # Shuffle
    XyXorig = list(zip(X, y, X_orig))
    random.shuffle(XyXorig)
    X,y,X_orig = zip(*XyXorig)
    X,y,X_orig = np.array(list(X)), np.array(list(y)), np.array(list(X_orig))

    return X, y, X_orig

# %%
# Execution
filepath = os.path.join(flags['SAVE_DIRECTORY'], flags['MODEL_NAME'])

with tf.Graph().as_default():
    with tf.Session() as sess:
        K.set_session(sess)

        # Load model
        print("Loading model...")
        model = load_model(filepath, custom_objects={'NoisyAnd': NoisyAnd})
        print("Model Loaded")
        
        # Load test set
        X_test, y_test, X_test_orig = build_dataset(flags['input_snippet_test_dir'], get_orig=True)
        
        print("X_test shape={}, y_test shape={}".format(X_test.shape, y_test.shape))
        y_test_proc = (y_test != 'has_pedestrian')
        print("y_test_proc shape:", y_test_proc.shape)
        # Evaluation
        y_test_one_hot = keras.utils.to_categorical(y_test_proc, num_classes=flags['NUM_CLASSES'], dtype='int')
        print(y_test_one_hot.shape)

        eval_acc = model.evaluate(X_test, y_test_one_hot)
        print("eval_acc (loss, precision): ", eval_acc)

        # Prediction (Manual)
        raw_preds = model.predict(X_test)
        processed_preds = np.argmax(raw_preds, axis=1)
        
        y_pred = (processed_preds == 0) # has pedestrian
        y_true = (y_test == 'has_pedestrian')
        print(classification_report(y_true, y_pred))

        # Print
#         for i in range(50):
        for i in range(len(X_test)):
            print("Ground Truth =", y_test[i], ", Prediction(has pedestrian)=",  processed_preds[i]==0, ", Raw Prediction =", raw_preds[i])
#             plt.imshow(X_test[i])
#             plt.show()
#             plt.imshow(X_test_orig[i])
#             plt.show()
# Out:
# Loading model...
# Model Loaded
# /share/pkg.7/python3/3.6.9/install/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   """
# X_test shape=(290, 128, 128, 1), y_test shape=(290,)
# y_test_proc shape: (290,)
# (290, 2)
# 290/290 [==============================] - 1s 2ms/step
# eval_acc (loss, precision):  [0.5905573022776637, 0.7931034564971924]
#               precision    recall  f1-score   support
#
#        False       0.84      0.72      0.78       145
#         True       0.76      0.86      0.81       145
#
#     accuracy                           0.79       290
#    macro avg       0.80      0.79      0.79       290
# weighted avg       0.80      0.79      0.79       290
#
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.940045   0.05995506]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03356611 0.96643394]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.38639426 0.61360574]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.02943581 0.97056425]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.6676512  0.33234876]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.89875096 0.10124904]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97088766 0.02911241]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.15917698 0.84082305]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.5882177  0.41178235]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.7598528  0.24014716]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.06641111 0.93358886]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9715701  0.02842991]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.48709327 0.5129067 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.95298225 0.04701772]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9715242  0.02847579]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.02976709 0.97023296]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.05895808 0.94104195]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03185248 0.9681475 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.04798318 0.95201683]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9715998  0.02840024]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9539357  0.04606429]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9480537 0.0519463]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03668782 0.96331215]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9715978  0.02840219]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.0802448 0.9197552]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.0460687  0.95393133]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03180724 0.96819276]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.41628897 0.583711  ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.94943494 0.05056512]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9711997  0.02880035]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.13369356 0.8663064 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9185229  0.08147708]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.22569883 0.7743012 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.61753404 0.38246593]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9715817  0.02841833]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9269057  0.07309429]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03211682 0.9678832 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.19632387 0.8036762 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.7622607  0.23773932]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97160035 0.02839966]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9709245 0.0290755]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.18983576 0.8101642 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.5290221 0.4709779]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.85834306 0.141657  ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03207908 0.96792096]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.5078189  0.49218115]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.08050177 0.9194982 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.04005067 0.95994925]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97093683 0.02906315]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9715997 0.0284003]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.24997409 0.7500259 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.45630065 0.54369926]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.80601496 0.19398506]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.6626745  0.33732548]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.64155257 0.35844737]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.04323227 0.9567677 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.90070945 0.09929056]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.14017993 0.85982   ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.6828903  0.31710967]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.0329769 0.9670231]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.04191078 0.95808923]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.46232247 0.5376775 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97160035 0.0283996 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9674896  0.03251037]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.13413095 0.86586905]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.966214   0.03378604]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.7057434  0.29425663]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9704579  0.02954205]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.07681542 0.9231846 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03330385 0.96669614]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.66930944 0.33069053]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97060823 0.02939169]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.93643844 0.06356153]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.82336146 0.17663856]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.16842292 0.8315771 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97069126 0.02930872]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.96802753 0.03197247]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.65098226 0.34901777]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9495329  0.05046704]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9643551  0.03564491]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9238895  0.07611045]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.86376417 0.13623582]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03078233 0.96921766]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03038247 0.9696175 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97084314 0.02915681]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.05505922 0.9449408 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.51670134 0.4832987 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.17859414 0.8214058 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.42006248 0.5799375 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.4719014 0.5280986]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97160035 0.0283996 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.05953221 0.94046783]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.08432924 0.91567075]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.6047254 0.3952746]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.36065394 0.63934606]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.15501668 0.8449833 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.29969066 0.70030934]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.78289926 0.21710078]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.92461514 0.07538489]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.04853481 0.9514652 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.19605124 0.80394876]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9645413  0.03545869]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97031826 0.02968175]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.36178365 0.6382164 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.53128135 0.46871874]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9715983  0.02840168]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.38407874 0.6159212 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03462164 0.96537834]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.95748025 0.04251979]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97147006 0.02852992]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.234626 0.765374]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9597146  0.04028536]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.87841725 0.12158274]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.969971   0.03002902]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.5091177  0.49088234]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03409614 0.9659038 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9325387  0.06746133]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.31223017 0.6877699 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.70828325 0.29171675]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.05548459 0.9445154 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.05970055 0.94029945]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.8752044  0.12479567]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9707206  0.02927944]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03094267 0.9690573 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.971593   0.02840695]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03937224 0.9606278 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03942381 0.9605762 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97159684 0.02840318]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97160023 0.0283998 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.05327179 0.94672817]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9715954  0.02840462]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97160035 0.0283996 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.47544143 0.52455854]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97003347 0.02996657]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03354483 0.9664552 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.06237527 0.93762475]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.05209448 0.9479055 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03133699 0.968663  ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.62494713 0.3750529 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.6750184  0.32498157]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9702407 0.0297593]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.7063459  0.29365405]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.5428977  0.45710233]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9713689  0.02863106]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9663756  0.03362435]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.26952213 0.73047787]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.030101 0.969899]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9714246  0.02857535]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9711782 0.0288218]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.18086506 0.81913495]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9714835  0.02851645]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03273512 0.96726495]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.5860335  0.41396654]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97160035 0.0283996 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9714164  0.02858355]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03058358 0.9694164 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.07935262 0.92064744]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9404721  0.05952786]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03402546 0.96597457]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.0596676 0.9403325]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.94582087 0.05417917]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9684155  0.03158447]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.96260536 0.03739465]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.6161603 0.3838397]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.971599   0.02840094]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97159857 0.02840149]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.08292694 0.917073  ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03817944 0.9618205 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.17748038 0.82251966]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.90691006 0.09308995]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.96114033 0.0388596 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.2701136 0.7298864]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.64607304 0.35392693]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03660753 0.9633925 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.02943689 0.9705631 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.28991017 0.71008986]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.5041975  0.49580255]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97159934 0.0284007 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.57633245 0.42366758]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03354451 0.9664555 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.20804664 0.7919534 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9340644  0.06593566]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9084489 0.0915511]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97149175 0.02850824]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.96235776 0.03764228]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.08162273 0.9183773 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9704441  0.02955588]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.02943484 0.97056514]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97066295 0.02933705]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.933127   0.06687305]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.56755084 0.4324492 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9549053 0.0450947]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9714248  0.02857515]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03411825 0.96588176]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.92551136 0.07448864]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97160035 0.0283996 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.6947489  0.30525112]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.3217911 0.6782088]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.02943811 0.97056186]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9543021  0.04569795]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97160023 0.02839975]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.04673699 0.95326304]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.10244956 0.89755046]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9712766  0.02872337]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03260772 0.9673923 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.96285206 0.03714798]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9703789  0.02962116]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.54506356 0.45493647]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03020284 0.9697972 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.971518   0.02848202]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97160035 0.0283997 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97000366 0.02999636]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9713761  0.02862386]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.28970698 0.710293  ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03283874 0.96716124]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97158843 0.02841152]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.78654057 0.21345943]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.6017624 0.3982376]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.15196368 0.8480363 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.11309823 0.8869018 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.96563596 0.03436405]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.89600897 0.103991  ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97159564 0.02840437]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03046293 0.969537  ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.7670071  0.23299289]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.02943573 0.97056425]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.16358286 0.83641714]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.45624396 0.543756  ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97158945 0.02841059]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.06188709 0.938113  ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.3302491 0.669751 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03334222 0.9666578 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.6990704  0.30092955]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.93087107 0.06912897]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9716001  0.02839991]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9692972  0.03070284]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.14372225 0.85627776]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.29617795 0.70382214]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9146742  0.08532576]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.09872078 0.9012793 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.19893394 0.80106604]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.02964326 0.97035676]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03135787 0.96864206]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97157526 0.02842475]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97056466 0.02943531]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.908357   0.09164295]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.6853958  0.31460428]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.06761006 0.93239   ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.4559298 0.5440702]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.95433855 0.04566145]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.96191305 0.03808691]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.12899283 0.87100714]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03112418 0.96887577]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.03097633 0.96902364]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.89836663 0.10163341]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.15361398 0.846386  ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.7567554  0.24324463]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9715998 0.0284002]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.96961516 0.03038481]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.12661192 0.8733881 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.02952033 0.97047967]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9715996 0.0284004]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9714343  0.02856577]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.15185201 0.84814805]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.04900764 0.9509923 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.81041193 0.18958804]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.02959516 0.9704048 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.8833531  0.11664693]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9715978  0.02840219]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9559739  0.04402605]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9702828  0.02971718]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.24168067 0.7583193 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.02945668 0.9705433 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97158706 0.02841292]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9713528  0.02864713]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.02964216 0.9703579 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.4045845  0.59541553]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.95138836 0.0486116 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9693647  0.03063531]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.94960904 0.0503909 ]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.04149092 0.9585091 ]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9712676  0.02873241]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.06224908 0.93775094]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.97159475 0.02840526]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.971244   0.02875597]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9623062  0.03769381]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= False , Raw Prediction = [0.05760932 0.94239074]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9177391  0.08226088]
# Ground Truth = no_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.90671676 0.09328319]
# Ground Truth = has_pedestrian , Prediction(has pedestrian)= True , Raw Prediction = [0.9604169  0.03958312]

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 220, 220, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 110, 110, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 108, 108, 64)      36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 22, 22, 1000)      1153000
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 22, 22, 2)         2002
# _________________________________________________________________
# noisy_and_1 (NoisyAnd)       (None, 2)                 2
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 6
# =================================================================
# Total params: 1,432,770
# Trainable params: 1,432,770
# Non-trainable params: 0
# _________________________________________________________________
